# %% [markdown]
# # Data science Tools and Ecosystem

# %% [markdown]
# In this notebook, data science tools and ecosytem are summaraised

# %% [markdown]
# some of the popular languages that data scientists use are:
# 1. python
# 2. R language
# 3. SQL
# 4. Java

# %% [markdown]
# some of the commonly used libraries used by data scientists include
# 1. ggplot2
# 2. dplyr
# 3. pandas
# 4. matplotlib
# 5. caret

# %% [markdown]
# | Data science tools|
# ------------
# |apache spark|
# |hadoop|
# |tensor flow|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
## This a simple arithmetic expression to mutiply then add integers

a = (3*4)+5
print (a)
# Out:
# 17

# %%
## This will convert 200 minutes to hours by diving by 60

MTH  = 200*(1/60)
print (MTH)
# Out:
# 3.3333333333333335

# %% [markdown]
# __Objectives__
# * creating markdown cells
# * creating cells
# * saving cells
# * typing text using markdown cells

# %% [markdown]
# ## __Author__
# LK
